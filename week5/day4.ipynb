# %% [markdown]
# # RAG Day 4
#
# ## Evaluation!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Keep in mind how you would evaluate RAG for your business</h2>
#             <span style="color:#181;">This is such an important part of building an accurate and reliable RAG pipeline. And it's applicable to many aspects of solving business problems with LLMs. People are often focused on RAG architecture and RAG frameworks for their business. But even more important: evaluations!</span>
#         </td>
#     </tr>
# </table>

# %%
from evaluation import test

# %%
tests = test.load_tests()

# %%
len(tests)
# Out:
# 150

# %%
example = tests[0]
print(example.question)
print(example.category)
print(example.reference_answer)
print(example.keywords)
# Out:
# Who won the prestigious IIOTY award in 2023?
# direct_fact
# Maxine Thompson won the prestigious Insurellm Innovator of the Year (IIOTY) award in 2023.
# ['Maxine', 'Thompson', 'IIOTY']

# %%
from collections import Counter
count = Counter([t.category for t in tests])
count
# Out:
# Counter({'direct_fact': 70,
#          'temporal': 20,
#          'spanning': 20,
#          'comparative': 10,
#          'numerical': 10,
#          'relationship': 10,
#          'holistic': 10})

# %%
from evaluation.eval import evaluate_retrieval, evaluate_answer
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
evaluate_retrieval(example)
# Out:
# RetrievalEval(mrr=0.16666666666666666, ndcg=0.29420493957109245, keywords_found=2, total_keywords=3, keyword_coverage=66.66666666666666)

# %%
eval, answer, chunks = evaluate_answer(example)
# Out:
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# File ~/projects/llm_lab/.venv/lib/python3.12/site-packages/litellm/llms/openai/openai.py:845, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params, shared_session)
#     844             else:
# --> 845                 raise e
#     846 except OpenAIError as e:
#
# File ~/projects/llm_lab/.venv/lib/python3.12/site-packages/litellm/llms/openai/openai.py:747, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params, shared_session)
#     744     raise OpenAIError(
#     745         status_code=422, message="max retries must be an int"
#     746     )
# --> 747 openai_client: OpenAI = self._get_openai_client(  # type: ignore
#     748     is_async=False,
#     749     api_key=api_key,
#     750     api_base=api_base,
#     751     api_version=api_version,
#     752     timeout=timeout,
#     753     max_retries=max_retries,
#     754     organization=organization,
#     755     client=client,
#     756 )
#     758 ## LOGGING
#
# File ~/projects/llm_lab/.venv/lib/python3.12/site-packages/litellm/llms/openai/openai.py:396, in OpenAIChatCompletion._get_openai_client(self, is_async, api_key, api_base, api_version, timeout, max_retries, organization, client, shared_session)
#     395 else:
# --> 396     _new_client = OpenAI(
#     397         api_key=api_key,
#     398         base_url=api_base,
#     399         http_client=OpenAIChatCompletion._get_sync_http_client(),
#     400         timeout=timeout,
#     401         max_retries=max_retries,
#     402         organization=organization,
#     403     )
#     405 ## SAVE CACHE KEY
#
# File ~/projects/llm_lab/.venv/lib/python3.12/site-packages/openai/_client.py:139, in OpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     138 if api_key is None:
# --> 139     raise OpenAIError(
#     140         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     141     )
#     142 if callable(api_key):
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
#
# During handling of the above exception, another exception occurred:
#
# OpenAIError                               Traceback (most recent call last)
# File ~/projects/llm_lab/.venv/lib/python3.12/site-packages/litellm/main.py:2609, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, verbosity, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    2603     logging.post_call(
#    2604         input=messages,
#    2605         api_key=api_key,
#    2606         original_response=str(e),
#    2607         additional_args={"headers": headers},
#    2608     )
# -> 2609     raise e
#    2611 if optional_params.get("stream", False):
#    2612     ## LOGGING
#
# File ~/projects/llm_lab/.venv/lib/python3.12/site-packages/litellm/main.py:2581, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, verbosity, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    2580     else:
# -> 2581         response = openai_chat_completions.completion(
#    2582             model=model,
#    2583             messages=messages,
#    2584             headers=headers,
#    2585             model_response=model_response,
#    2586             print_verbose=print_verbose,
#    2587             api_key=api_key,
#    2588             api_base=api_base,
#    2589             acompletion=acompletion,
#    2590             logging_obj=logging,
#    2591             optional_params=optional_params,
#    2592             litellm_params=litellm_params,
#    2593             logger_fn=logger_fn,
#    2594             timeout=timeout,  # type: ignore
#    2595             custom_prompt_dict=custom_prompt_dict,
#    2596             client=client,  # pass AsyncOpenAI, OpenAI client
#    2597             organization=organization,
#    2598             custom_llm_provider=custom_llm_provider,
#    2599             shared_session=shared_session,
#    2600         )
#    2601 except Exception as e:
#    2602     ## LOGGING - log the original exception returned
#
# File ~/projects/llm_lab/.venv/lib/python3.12/site-packages/litellm/llms/openai/openai.py:856, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params, shared_session)
#     855     error_headers = getattr(error_response, "headers", None)
# --> 856 raise OpenAIError(
#     857     status_code=status_code,
#     858     message=error_text,
#     859     headers=error_headers,
#     860     body=error_body,
#     861 )
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
#
# During handling of the above exception, another exception occurred:
#
# AuthenticationError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 eval, answer, chunks = evaluate_answer(example)
#
# File ~/projects/llm_lab/week5/evaluation/eval.py:156, in evaluate_answer(test)
#     130 judge_messages = [
#     131     {
#     132         "role": "system",
#    (...)    152     },
#     153 ]
#     155 # Call LLM judge with structured outputs (async)
# --> 156 judge_response = completion(model=MODEL, messages=judge_messages, response_format=AnswerEval)
#     158 answer_eval = AnswerEval.model_validate_json(judge_response.choices[0].message.content)
#     160 return answer_eval, generated_answer, retrieved_docs
#
# File ~/projects/llm_lab/.venv/lib/python3.12/site-packages/litellm/utils.py:1749, in client.<locals>.wrapper(*args, **kwargs)
#    1745 if logging_obj:
#    1746     logging_obj.failure_handler(
#    1747         e, traceback_exception, start_time, end_time
#    1748     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1749 raise e
#
# File ~/projects/llm_lab/.venv/lib/python3.12/site-packages/litellm/utils.py:1570, in client.<locals>.wrapper(*args, **kwargs)
#    1568         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1569 # MODEL CALL
# -> 1570 result = original_function(*args, **kwargs)
#    1571 end_time = datetime.datetime.now()
#    1572 if _is_streaming_request(
#    1573     kwargs=kwargs,
#    1574     call_type=call_type,
#    1575 ):
#
# File ~/projects/llm_lab/.venv/lib/python3.12/site-packages/litellm/main.py:4320, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, verbosity, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, **kwargs)
#    4317     return response
#    4318 except Exception as e:
#    4319     ## Map to OpenAI Exception
# -> 4320     raise exception_type(
#    4321         model=model,
#    4322         custom_llm_provider=custom_llm_provider,
#    4323         original_exception=e,
#    4324         completion_kwargs=args,
#    4325         extra_kwargs=kwargs,
#    4326     )
#
# File ~/projects/llm_lab/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:2398, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2396 if exception_mapping_worked:
#    2397     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2398     raise e
#    2399 else:
#    2400     for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# File ~/projects/llm_lab/.venv/lib/python3.12/site-packages/litellm/litellm_core_utils/exception_mapping_utils.py:483, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#     478 elif (
#     479     "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     480     in error_str
#     481 ):
#     482     exception_mapping_worked = True
# --> 483     raise AuthenticationError(
#     484         message=f"AuthenticationError: {exception_provider} - {message}",
#     485         llm_provider=custom_llm_provider,
#     486         model=model,
#     487         response=getattr(original_exception, "response", None),
#     488         litellm_debug_info=extra_information,
#     489     )
#     490 elif "Mistral API raised a streaming error" in error_str:
#     491     exception_mapping_worked = True
#
# AuthenticationError: litellm.AuthenticationError: AuthenticationError: OpenAIException - The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
eval
