# %% [markdown]
# ## First - let's talk about the Chat Completions API
#
# 1. The simplest way to call an LLM
# 2. It's called Chat Completions because it's saying: "here is a conversation, please predict what should come next"
# 3. The Chat Completions API was invented by OpenAI, but it's so popular that everybody uses it!
#
# ### We will start by calling OpenAI again - but don't worry non-OpenAI people, your time is coming!

# %%
import os
from dotenv import load_dotenv

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook

# %% [markdown]
# ## Do you know what an Endpoint is?
#
# If not, please review the Technical Foundations guide in the guides folder
#
# And, here is an endpoint that might interest you...

# %%
import requests

headers = {"Authorization": f"Bearer {api_key}", "Content-Type": "application/json"}

payload = {
    "model": "gpt-5-nano",
    "messages": [
        {"role": "user", "content": "Tell me a fun fact"}]
}

payload
# Out:
# {'model': 'gpt-5-nano',
#  'messages': [{'role': 'user', 'content': 'Tell me a fun fact'}]}

# %%
response = requests.post(
    "https://openrouter.ai/api/v1/chat/completions",
    headers=headers,
    json=payload
)

response.json()
# Out:
# {'id': 'gen-1772204963-lWL3vcQotiSzIwnZHIkF',
#  'provider': 'OpenAI',
#  'model': 'openai/gpt-5-nano',
#  'object': 'chat.completion',
#  'created': 1772204963,
#  'choices': [{'logprobs': None,
#    'finish_reason': 'stop',
#    'native_finish_reason': 'completed',
#    'index': 0,
#    'message': {'role': 'assistant',
#     'content': 'Fun fact: Honey never spoils. Archaeologists have found pots of honey in ancient tombs that are still edible after thousands of years.',
#     'refusal': None,
#     'reasoning': '**Finding a fun fact**\n\nI need to respond to the user with a fun fact, which they requested. I want to make sure it\'s interesting and concise, maybe focusing on animals, space, history, or science. I\'ll prepare a single sentence or two with a brief explanation. A good choice is the classic, "Honey never spoils; archaeologists have found pots of honey in ancient tombs that are still edible." I think that’s a surprising yet relatable fact!**Choosing a fun fact**\n\nI’m thinking about different fun facts to share. One interesting option is that "Bananas are technically berries, while strawberries aren\'t." I can follow that up with a brief explanation about what makes a berry, but I want to keep it concise. Another great option is, "Humans share about 98% of DNA with chimpanzees," which is both accurate and fascinating. However, I’ve decided to go with "Honey never spoils," as it\'s surprising and straightforward.**Crafting a fun fact**\n\nI want to share a fun fact that’s both interesting and accurate. Honey is known for never spoiling; archaeologists have discovered pots of honey in ancient Egyptian tombs that remain edible even after thousands of years. That\'s a classic fact and fits perfectly since the user simply asked for "a fun fact." I’ll present it clearly without needing additional options or disclaimers. Here we go: "Fun fact: Honey never spoils!" Sounds good!',
#     'reasoning_details': [{'format': 'openai-responses-v1',
#       'index': 0,
#       'type': 'reasoning.summary',
#       'summary': '**Finding a fun fact**\n\nI need to respond to the user with a fun fact, which they requested. I want to make sure it\'s interesting and concise, maybe focusing on animals, space, history, or science. I\'ll prepare a single sentence or two with a brief explanation. A good choice is the classic, "Honey never spoils; archaeologists have found pots of honey in ancient tombs that are still edible." I think that’s a surprising yet relatable fact!**Choosing a fun fact**\n\nI’m thinking about different fun facts to share. One interesting option is that "Bananas are technically berries, while strawberries aren\'t." I can follow that up with a brief explanation about what makes a berry, but I want to keep it concise. Another great option is, "Humans share about 98% of DNA with chimpanzees," which is both accurate and fascinating. However, I’ve decided to go with "Honey never spoils," as it\'s surprising and straightforward.**Crafting a fun fact**\n\nI want to share a fun fact that’s both interesting and accurate. Honey is known for never spoiling; archaeologists have discovered pots of honey in ancient Egyptian tombs that remain edible even after thousands of years. That\'s a classic fact and fits perfectly since the user simply asked for "a fun fact." I’ll present it clearly without needing additional options or disclaimers. Here we go: "Fun fact: Honey never spoils!" Sounds good!'},
#      {'id': 'rs_0d7fd922991445dd0169a1b3a43eb481938e0400d42ac2b19c',
#       'format': 'openai-responses-v1',
#       'index': 1,
#       'type': 'reasoning.encrypted',
uSIKcvFkIXhTTzyAf33_29WYrJntXXUFTRkpaDI6zf0naKjldF0--CL_nqe8eNSMHh8X-Rc-k6L-mjBMUwcP2iAnshxnlLMllI02Dbe91WJ5aQLJapqp07Pv5Yj5mYO1N4OAt7hI97QXJSJ5BPp1PRoU2OQ-emcjCsuXDv29ijTFc5kL9ywz18_f469Ypg8HyA3kScOu95MCH2d_4zick8eJAHdY3wfxNzLsyO101d7f5wukyyY5ZMgnKE7X0ty6vwc-Z-NO6YNwrLbBLnVPeLH1ogaUCYg-bTsf1oe7BZp2brXNA6qRu_yrm6yy_DJTdvQaZwN6QWGQmGHzK3ybAwK6rJMEPF7AufpuYEttrcbVh9E07xW3S-vipFv5VERuPXIHzYmPD_0IsJnODPXYyL9D5xTkG7xAyFmJLWSNTk1nM5sNf7tpUJmu2DQC-fTDiDhCGSVM-Vm2MHB51X7C4aAXmtNMzvAysHkF8tGzt641qf8rt_h5hIdWump6geFIgvwiNkghS-4P0lO5j2r_1JwENH8V28v4J_UO ...
#  'usage': {'prompt_tokens': 11,
#   'completion_tokens': 627,
#   'total_tokens': 638,
#   'cost': 0.00025135,
#   'is_byok': False,
#   'prompt_tokens_details': {'cached_tokens': 0},
#   'cost_details': {'upstream_inference_cost': 0.00025135,
#    'upstream_inference_prompt_cost': 5.5e-07,
#    'upstream_inference_completions_cost': 0.0002508},
#   'completion_tokens_details': {'reasoning_tokens': 576, 'image_tokens': 0}}}

# %%
response.json()["choices"][0]["message"]["content"]
# Out:
# 'Fun fact: Honey never spoils. Archaeologists have found pots of honey in ancient tombs that are still edible after thousands of years.'

# %% [markdown]
# # What is the openai package?
#
# It's known as a Python Client Library.
#
# It's nothing more than a wrapper around making this exact call to the http endpoint.
#
# It just allows you to work with nice Python code instead of messing around with janky json objects.
#
# But that's it. It's open-source and lightweight. Some people think it contains OpenAI model code - it doesn't!

# %%
# Create OpenAI client

from openai import OpenAI

openai = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY"),
    base_url=os.getenv("OPENROUTER_BASE_URL")
)

response = openai.chat.completions.create(model="openai/gpt-5-nano", messages=[{"role": "user", "content": "Tell me a fun fact"}])

response.choices[0].message.content
# Out:
# 'Fun fact: A day on Venus is longer than a year on Venus. It takes about 243 Earth days to rotate once, but only about 225 Earth days to orbit the Sun. Want another fun fact?'

# %% [markdown]
# ## And then this great thing happened:
#
# OpenAI's Chat Completions API was so popular, that the other model providers created endpoints that are identical.
#
# They are known as the "OpenAI Compatible Endpoints".
#
# For example, google made one here: https://generativelanguage.googleapis.com/v1beta/openai/
#
# And OpenAI decided to be kind: they said, hey, you can just use the same client library that we made for GPT. We'll allow you to specify a different endpoint URL and a different key, to use another provider.
#
# So you can use:
#
# ```python
# gemini = OpenAI(base_url="https://generativelanguage.googleapis.com/v1beta/openai/", api_key="AIz....")
# gemini.chat.completions.create(...)
# ```
#
# And to be clear - even though OpenAI is in the code, we're only using this lightweight python client library to call the endpoint - there's no OpenAI model involved here.
#
# If you're confused, please review Guide 9 in the Guides folder!
#
# And now let's try it!
#
# ## THIS IS OPTIONAL - but if you wish to try out Google Gemini, please visit:
#
# https://aistudio.google.com/
#
# And set up your API key at
#
# https://aistudio.google.com/api-keys
#
# And then add your key to the `.env` file, being sure to Save the .env file after you change it:
#
# `GOOGLE_API_KEY=AIz...`

# %%
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"

load_dotenv(override=True)

google_api_key = os.getenv("GOOGLE_API_KEY")

if not google_api_key:
    print("No API key was found - please be sure to add your key to the .env file, and save the file! Or you can skip the next 2 cells if you don't want to use Gemini")
elif not google_api_key.startswith("AIz"):
    print("An API key was found, but it doesn't start AIz")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key=google_api_key)

response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=[{"role": "user", "content": "Tell me a fun fact"}])

response.choices[0].message.content
# Out:
# "Here's a fun one:\n\n**Octopuses have three hearts!** Two hearts pump blood to the gills, and one larger heart pumps blood to the rest of the body."
