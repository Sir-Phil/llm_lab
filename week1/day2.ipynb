# %% [markdown]
# ## First - let's talk about the Chat Completions API
#
# 1. The simplest way to call an LLM
# 2. It's called Chat Completions because it's saying: "here is a conversation, please predict what should come next"
# 3. The Chat Completions API was invented by OpenAI, but it's so popular that everybody uses it!
#
# ### We will start by calling OpenAI again - but don't worry non-OpenAI people, your time is coming!

# %%
import os
from dotenv import load_dotenv

load_dotenv(override=True)
api_key = os.getenv('OPENROUTER_API_KEY')

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook

# %% [markdown]
# ## Do you know what an Endpoint is?
#
# If not, please review the Technical Foundations guide in the guides folder
#
# And, here is an endpoint that might interest you...

# %%
import requests

headers = {"Authorization": f"Bearer {api_key}", "Content-Type": "application/json"}

payload = {
    "model": "gpt-5-nano",
    "messages": [
        {"role": "user", "content": "Tell me a fun fact"}]
}

payload
# Out:
# {'model': 'gpt-5-nano',
#  'messages': [{'role': 'user', 'content': 'Tell me a fun fact'}]}

# %%
response = requests.post(
    "https://openrouter.ai/api/v1/chat/completions",
    headers=headers,
    json=payload
)

response.json()
# Out:
# {'id': 'gen-1772193345-E9wI6PYeme2WCEcinOwG',
#  'provider': 'OpenAI',
#  'model': 'openai/gpt-5-nano',
#  'object': 'chat.completion',
#  'created': 1772193345,
#  'choices': [{'logprobs': None,
#    'finish_reason': 'stop',
#    'native_finish_reason': 'completed',
#    'index': 0,
#    'message': {'role': 'assistant',
#     'content': "Here's a fun fact: Bananas are berries, but strawberries aren’t. Botanically, a berry is a fruit that develops from a single ovary and contains seeds inside; bananas fit that definition, while strawberries are aggregate fruits made from many tiny ovaries. Want another fun fact?",
#     'refusal': None,
#     'reasoning': '**Providing fun facts**\n\nThe user asked for a fun fact, so I need to respond with something interesting and harmless. It might be cool to provide a few options so the user can choose. Since it\'s a simple request, I\'ll keep it concise. I think I\'ll offer 2-3 fun facts and even ask if they want a specific category. Although giving just one fact works too, offering multiple could be more engaging. I\'ll go with three short facts, each just a sentence long!**Listing fun facts**\n\nI want to make sure I provide accurate fun facts. Here are a few intriguing options: Bananas are berries, but strawberries aren\'t because of how they\'re classified. A day on Venus lasts longer than its year, taking about 243 Earth days to rotate, while it orbits the sun in about 225 days. Honey never spoils; archaeologists have found edible pots in ancient tombs! Also, octopuses have three hearts, and they even have blue blood. That’s quite fascinating!**Clarifying fun facts**\n\nI realized the claim about "more possible chess games than atoms in the universe" isn\'t precise. The number of legal chess positions is around 10^47, which is less than the estimated 10^80 atoms in the universe! However, the number of unique chess games is about 10^120, exceeding the atom count. Now, here are some fun facts: A group of flamingos is called a flamboyance, wombats have cube-shaped poop to mark territory, and there are about 3 trillion trees on Earth, outnumbering the Milky Way stars!**Sharing fun facts**\n\nLet’s dive into some fun facts! First, Mercury has a solar day of about 176 Earth days, which is longer than its year of 88 days. The shortest war in history was between Britain and Zanzibar in 1896, lasting only 38 to 45 minutes. Cows actually have best friends and get stressed when they\'re separated! Fred Baur, the inventor of the Pringles can, is buried in one, and fun fact: a cloud can weigh over a million pounds!**Delivering a fun fact**\n\nThe user asked for a fun fact, so I\'ll start with one and see if they\'d like more. Here goes: "Here\'s a fun fact: Bananas are berries, but strawberries aren\'t. Botanically, a berry is defined as a fruit that develops from a single ovary and contains seeds inside, which bananas do. In contrast, strawberries are aggregate fruits made from multiple tiny ovaries. Would you like another fun fact or maybe something from a specific category?" That should be a nice way to engage!',
#     'reasoning_details': [{'format': 'openai-responses-v1',
#       'index': 0,
#       'type': 'reasoning.summary',
#       'summary': '**Providing fun facts**\n\nThe user asked for a fun fact, so I need to respond with something interesting and harmless. It might be cool to provide a few options so the user can choose. Since it\'s a simple request, I\'ll keep it concise. I think I\'ll offer 2-3 fun facts and even ask if they want a specific category. Although giving just one fact works too, offering multiple could be more engaging. I\'ll go with three short facts, each just a sentence long!**Listing fun facts**\n\nI want to make sure I provide accurate fun facts. Here are a few intriguing options: Bananas are berries, but strawberries aren\'t because of how they\'re classified. A day on Venus lasts longer than its year, taking about 243 Earth days to rotate, while it orbits the sun in about 225 days. Honey never spoils; archaeologists have found edible pots in ancient tombs! Also, octopuses have three hearts, and they even have blue blood. That’s quite fascinating!**Clarifying fun facts**\n\nI realized the claim about "more possible chess games than atoms in the universe" isn\'t precise. The number of legal chess positions is around 10^47, which is less than the estimated 10^80 atoms in the universe! However, the number of unique chess games is about 10^120, exceeding the atom count. Now, here are some fun facts: A group of flamingos is called a flamboyance, wombats have cube-shaped poop to mark territory, and there are about 3 trillion trees on Earth, outnumbering the Milky Way stars!**Sharing fun facts**\n\nLet’s dive into some fun facts! First, Mercury has a solar day of about 176 Earth days, which is longer than its year of 88 days. The shortest war in history was between Britain and Zanzibar in 1896, lasting only 38 to 45 minutes. Cows actually have best friends and get stressed when they\'re separated! Fred Baur, the inventor of the Pringles can, is buried in one, and fun fact: a cloud can weigh over a million pounds!**Delivering a fun fact**\n\nThe user asked for a fun fact, so I\'ll start with one and see if they\'d like more. Here goes: "Here\'s a fun fact: Bananas are berries, but strawberries aren\'t. Botanically, a berry is defined as a fruit that develops from a single ovary and contains seeds inside, which bananas do. In contrast, strawberries are aggregate fruits made from multiple tiny ovaries. Would you like another fun fact or maybe something from a specific category?" That should be a nice way to engage!'},
#      {'id': 'rs_00e983eaf30f0c480169a18641ed8c81948c8204c24a904c51',
#       'format': 'openai-responses-v1',
#       'index': 1,
#       'type': 'reasoning.encrypted',
#       'data': 'gAAAAABpoYZTzEiw8VxRgEv4G7pMlyc2grSebTaHrsfZf61itaLwJmWKHyydVV2zIaqD77MnJmn8fW45i7Y_X_6VPJ5S_uT7LUtcM9_Ni826tb8__ryrVzA8IyQxNqcI-fAVc1VamrGyqzUO6avDooU-aHj-N-S2GUoQy0V-gtGZDvXzZfftunZSEhlv5TJYYQPfx2gdnwPVHDFzAeF9t1fux7yywPiaFnaBguJm73Xjs4t50nABwcGYvbdxAAsWch7lnPkN38LUbVIqwGXZ74xu4bFy7SysWq9VrovLSp5IkyoeQIyMWn8LycVlanlR3qfYCZchvibm0UFht2_HfQ3crPVDIQRRPPwXUueWeGHNfXhOtM7sC6hIuVhIFfmV48hfy_LtiTGL6hfvNvetG3Y4_1srkvzVnRGITJ66OUFxZdkAwNDjxE8q0yrVBjTLLK8SuPYAgOLLlUR0nbo9lzIF8FCF-a01EZXBEAk2Z1b16utnGE3F40sH5M3mev7EMkCdsM2p9-HGVb4NFSeX0JUDBorrkWzIGLWOkbVvhQ6QE5Hd97PYvv1fu-3odiZxyEG7UekQIcYpim9AnHDKXDazuPYFLJWIwwe6YQiE56VTYwipXAlDaaeEETeW4jPky9vEatGI
_LHDbv8lTqZkqsjE1sQKV_4k2sMSelL8jt_UcP89yGkk9JfFBgW0n_81sm-VFZkpVXKxvfbYUQ5MmuPpyvgxFQlUJ770Kpg9E11pmZ2LDTp_HSSGKztzSsAOCRRb_mQ02mU5y5Y87gJm72z1tPVcPJjjVs_XAW8eu5in-o9UAH93WdTem_0b1ZATmPRdwgLk3br1PlRTQesLESUKVwX21iG5fineZ95QQy4Qd2wArhTW1UzgEPF7ueSqxfnbp6yy3yLUBYxvr465fTTIXDbnIYJUvV0ob3eOuPuzFJ_IKh5r3ULXGfTRWbc6sZALKy0-BEEXivG4flXmm3r-CInH4FCQdTp3rfjceVHFqZV ...
#  'usage': {'prompt_tokens': 11,
#   'completion_tokens': 1186,
#   'total_tokens': 1197,
#   'cost': 0.00047495,
#   'is_byok': False,
#   'prompt_tokens_details': {'cached_tokens': 0},
#   'cost_details': {'upstream_inference_cost': 0.00047495,
#    'upstream_inference_prompt_cost': 5.5e-07,
#    'upstream_inference_completions_cost': 0.0004744},
#   'completion_tokens_details': {'reasoning_tokens': 1088, 'image_tokens': 0}}}

# %%
response.json()["choices"][0]["message"]["content"]
# Out:
# "Here's a fun fact: Bananas are berries, but strawberries aren’t. Botanically, a berry is a fruit that develops from a single ovary and contains seeds inside; bananas fit that definition, while strawberries are aggregate fruits made from many tiny ovaries. Want another fun fact?"

# %% [markdown]
# # What is the openai package?
#
# It's known as a Python Client Library.
#
# It's nothing more than a wrapper around making this exact call to the http endpoint.
#
# It just allows you to work with nice Python code instead of messing around with janky json objects.
#
# But that's it. It's open-source and lightweight. Some people think it contains OpenAI model code - it doesn't!

# %%
# Create OpenAI client

from openai import OpenAI
openai = OpenAI()

client = OpenAI(
    api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url=os.getenv("OPENROUTER_BASE_URL")
)

response = client.chat.completions.create(model="openai/gpt-5-nano", messages=[{"role": "user", "content": "Tell me a fun fact"}])

response.choices[0].message.content
# Out:
# 'Fun fact: Wombats poop cubes. Their slow digestion and the way their intestines squeeze and dry the waste create cube-shaped pellets, which helps them stack and not roll away. Want another fun fact on a different topic?'

# %% [markdown]
# ## And then this great thing happened:
#
# OpenAI's Chat Completions API was so popular, that the other model providers created endpoints that are identical.
#
# They are known as the "OpenAI Compatible Endpoints".
#
# For example, google made one here: https://generativelanguage.googleapis.com/v1beta/openai/
#
# And OpenAI decided to be kind: they said, hey, you can just use the same client library that we made for GPT. We'll allow you to specify a different endpoint URL and a different key, to use another provider.
#
# So you can use:
#
# ```python
# gemini = OpenAI(base_url="https://generativelanguage.googleapis.com/v1beta/openai/", api_key="AIz....")
# gemini.chat.completions.create(...)
# ```
#
# And to be clear - even though OpenAI is in the code, we're only using this lightweight python client library to call the endpoint - there's no OpenAI model involved here.
#
# If you're confused, please review Guide 9 in the Guides folder!
#
# And now let's try it!
#
# ## THIS IS OPTIONAL - but if you wish to try out Google Gemini, please visit:
#
# https://aistudio.google.com/
#
# And set up your API key at
#
# https://aistudio.google.com/api-keys
#
# And then add your key to the `.env` file, being sure to Save the .env file after you change it:
#
# `GOOGLE_API_KEY=AIz...`

# %%
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"

load_dotenv(override=True)

google_api_key = os.getenv("GOOGLE_API_KEY")

if not google_api_key:
    print("No API key was found - please be sure to add your key to the .env file, and save the file! Or you can skip the next 2 cells if you don't want to use Gemini")
elif not google_api_key.startswith("AIz"):
    print("An API key was found, but it doesn't start AIz")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key=google_api_key)

response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=[{"role": "user", "content": "Tell me a fun fact"}])

response.choices[0].message.content
# Out:
# "Here's a fun one:\n\n**Octopuses have three hearts!** Two hearts pump blood to the gills, and one larger heart pumps blood to the rest of the body."
