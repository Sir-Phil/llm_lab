# %% [markdown]
# ## Creating Minute Taker

# %%
from minute_taker import (
    transcribe_audio,
    generate_minutes,
    send_email_with_attachment,
    export_to_pdf
)

import gradio as gr

# %%
# def process_meeting(audio_file_path, email_address):
#     # audio_file_path is already a string from gr.Audio(type="filepath")
#     transcript = transcribe_audio(audio_file_path)

#     minutes = generate_minutes(transcript)

#     pdf_file = export_to_pdf(minutes)

#     send_email_with_attachment(
#         to_email=email_address,
#         subject="Meeting Minutes",
#         body="Attached are your AI-generated meeting minutes.",
#         attachment_path=pdf_file
#     )

#     return transcript, minutes, pdf_file

def process_meeting(audio_file_path, email_address):
    transcript = transcribe_audio(audio_file_path)
    minutes = generate_minutes(transcript)
    pdf_file = export_to_pdf(minutes)
    send_email_with_attachment(
        to_email=email_address,
        subject="Meeting Minutes",
        body="Attached are your AI-generated meeting minutes.",
        attachment_path=pdf_file
    )
    return transcript, minutes, pdf_fil

# %%
import gradio as gr

with gr.Blocks() as demo:
    gr.Markdown("# 🎙 AI Meeting Assistant")

    audio_input = gr.Audio(
        label="Record Meeting Audio",
        type="filepath",
        #tool="microphone"
    )
    email_input = gr.Textbox(label="Email Address")
    btn = gr.Button("Generate & Email Minutes")
    transcript_output = gr.Textbox(label="Transcript", lines=10)
    json_output = gr.JSON(label="Structured Minutes")
    file_output = gr.File(label="Download PDF")

    btn.click(
        process_meeting,
        inputs=[audio_input, email_input],
        outputs=[transcript_output, json_output, file_output]
    )

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "/Users/sirphiltechpaxe/projects/llm_lab/.venv/lib/python3.12/site-packages/gradio/queueing.py", line 766, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sirphiltechpaxe/projects/llm_lab/.venv/lib/python3.12/site-packages/gradio/route_utils.py", line 355, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sirphiltechpaxe/projects/llm_lab/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 2157, in process_api
#     result = await self.call_function(
# ...
